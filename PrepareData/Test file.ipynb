# %%
# train_path = 'C:\\Users\\Suhas\\Documents\\SeavusDataset\\da_train\\'
# lineid = 1
# with open('train.tsv', mode='w', newline='') as train:
#     writer = csv.writer(train, delimiter='\t')
#     for filename in os.listdir(train_path):
#         file = open(train_path + filename, "r")
#         temp = []
#         da = ''
#         for line in file:
#             temp = line.split()[2:-1]
#             temp = ' '.join(temp)
#             da = line.split()[-1].split('_')[2]
#             da = condenseDA(da)
#             sents = wrap(temp,125)
#             for sent in sents:
#                 try:
# #                     print([lineid, da, 'a', sent])
#                     writer.writerow([lineid, da, 'a', sent])
#                 except:
#                     pass
#                 lineid += 1
# #         print([lineid, '6', 'a', ' '])
#         writer.writerow([lineid, '6', 'a', ' '])
#         lineid += 1

# %%
# dev_path = 'C:\\Users\\Suhas\\Documents\\SeavusDataset\\da_dev\\'
# lineid = 1
# with open('dev.tsv', mode='w', newline='') as dev:
#     writer = csv.writer(dev, delimiter='\t')
#     for filename in os.listdir(dev_path):
#         file = open(dev_path + filename, "r")
#         temp = []
#         da = ''
#         for line in file:
#             temp = line.split()[2:-1]
#             temp = ' '.join(temp)
#             da = line.split()[-1].split('_')[2]
            
#             # Condense the Dialogue Acts Classes
#             if da == '1' or da == '2' or da == '3': #Segmentation = Fragment + Backchannel + Stall
#                 da = '1'
#             elif da == '4' or da == '5': #Information = Inform + Elicit Inform
#                 da = '2'
#             elif da == '6' or da == '7' or da == '8': #Actions = Suggest + Offer + Elicit Offer or Suggestion
#                 da = '3'
#             elif da == '9' or da == '11' or da == '12' or da == '13': #Discussion = Assessment + Comment about Understanding + Elicit Assessment + Elicit Comment about Understanding
#                 da = '4'
#             elif da == '14' or da == '15': #Social = Be Positive + Be Negative
#                 da = '5'
#             elif da == '16': #Other
#                 da = '6'
                
#             sents = wrap(temp,125)
# #             sents = nltk.sent_tokenize(temp)
#             for sent in sents:
#                 try:
# #                     print([lineid, da, 'a', sent])
#                     writer.writerow([lineid, da, 'a', sent])
#                 except:
#                     pass
#                 lineid += 1
# #         print([lineid, '6', 'a', ' '])
#         writer.writerow([lineid, '6', 'a', ' '])
#         lineid += 1

# %%
# test_path = 'C:\\Users\\Suhas\\Documents\\SeavusDataset\\da_test\\'
# lineid = 1
# with open('test.tsv', mode='w', newline='') as test:
#     writer = csv.writer(test, delimiter='\t')
#     writer.writerow(['id', 'sentence'])
#     for filename in os.listdir(test_path):
#         file = open(test_path + filename, "r")
#         temp = []
#         for line in file:
#             temp = line.split()[2:-1]
#             if len(temp) <=2:
#                 continue
#             temp = ' '.join(temp)
            
#             sents = wrap(temp,125)
#             for sent in sents:
#                 try:
# #                     print([lineid, temp])
#                     writer.writerow([lineid, temp])
#                 except:
#                     pass
#                 lineid += 1
# #             print([lineid, ' '])
#         writer.writerow([lineid, ' '])
#         lineid += 1

# %%
# test_path = 'C:\\Users\\Suhas\\Documents\\SeavusDataset\\da_test\\'
# lineid = 1
# with open('test_res.tsv', mode='w', newline='') as test:
#     writer = csv.writer(test, delimiter='\t')
# #     writer.writerow(['id', 'class', 'a', 'sentence'])
#     for filename in os.listdir(test_path):
#         file = open(test_path + filename, "r")
#         temp = []
#         for line in file:
#             temp = line.split()[2:-1]
#             temp = ' '.join(temp)
#             da = line.split()[-1].split('_')[2]
            
#             # Condense the Dialogue Acts Classes
#             if da == '1' or da == '2' or da == '3': #Segmentation = Fragment + Backchannel + Stall
#                 da = '1'
#             elif da == '4' or da == '5': #Information = Inform + Elicit Inform
#                 da = '2'
#             elif da == '6' or da == '7' or da == '8': #Actions = Suggest + Offer + Elicit Offer or Suggestion
#                 da = '3'
#             elif da == '9' or da == '11' or da == '12' or da == '13': #Discussion = Assessment + Comment about Understanding + Elicit Assessment + Elicit Comment about Understanding
#                 da = '4'
#             elif da == '14' or da == '15': #Social = Be Positive + Be Negative
#                 da = '5'
#             elif da == '16': #Other
#                 da = '6'
                
#             sents = wrap(temp,125)
# #             sents = nltk.sent_tokenize(temp)
#             for sent in sents:
#                 try:
# #                     print([lineid, da, 'a', sent])
#                     writer.writerow([lineid, da, 'a', sent])
#                 except:
#                     pass
#                 lineid += 1
# #         print([lineid, '6', 'a', ' '])
#         writer.writerow([lineid, '6', 'a', ' '])
#         lineid += 1

# %%
#         #Threshold 
#         new = max(fields)
#         if new >= '0.29':
#             best = np.argmax(fields) + 1
#         else:
#             best = 6
#         results.append(best)
        
#        #Normalize
#         f = [float(i) for i in fields]
#         max1 = max(f)
#         for i in f:
#             norm1 = float(i)/max1
#         print(norm1)
